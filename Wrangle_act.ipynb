# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# This project makes part of the coursework leading to Udacity's Data Analysis Nanodegree (DAND). Its objective is to demonstrate skills for the Data Wrangling phase of the Data Analysis Process. Data Wrangling is a key part in analytics, and is typically described as the one where analysts and data scientists spend the most part of their time.
#
# The project gathers data from different sources related to the WeRateDogs twitter account, which posts and rates photos of folowers' dogs. After assessing and cleaning the data, reports are written to communicate the results of an initial analysis.

# %%
# Import the required packages


# Import Libraries

# Data science
import pandas as pd
import tweepy as tw
import requests
import json
import os
import numpy as np

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting Pretty figures and avoiding blurry images
# %config InlineBackend.figure_format = 'retina'

# Larger scale for plots in notebooks
sns.set_context('notebook')

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression



# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)
# 2. A file downloaded programatically, with breed predictions for each dog
# 3. Additional data about each tweet (retweets and fav's), retrieved from Twitter's API

# %% [markdown]
# ### Import a File on hand into a padas dataframe

# %%
# Import file with twitter posts as a pandas dataframe
feed = pd.read_csv('twitter-archive-enhanced.csv')

# %% [markdown]
# ### Dowload a file from the Internet programatically

# %%
# Programatically download the datafile with breed predictions based on the tweet's image from a URL to insure reproducibility
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)
with open(os.path.join(url.split('/')[-1]), mode='wb') as file:
        file.write(response.content)
        
predictions = pd.read_csv('image-predictions.tsv', sep='\t')

# %% [markdown]
# ### Retrieve additional data from Twitter APIs, for each of the tweets in twitter-archive-enhanced.csv

# %% [markdown]
# Each tweet's retweet count and favorite ("like") count at minimum, and any additional data you find interesting. Using the tweet IDs in the WeRateDogs Twitter archive, query the Twitter API for each tweet's JSON data using Python's Tweepy library and store each tweet's entire set of JSON data in a file called tweet_json.txt file. Each tweet's JSON data should be written to its own line. Then read this .txt file line by line into a pandas DataFrame with (at minimum) tweet ID, retweet count, and favorite count.

# %%
# Twitter keys (delete before sharing)
consumer_key=""
consumer_secret=""
access_token=""
access_token_secret=""

# %%
# query the Twitter API for each tweet's JSON data using Python's Tweepy
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tw.API(auth, wait_on_rate_limit = True)

# %%
# Dataframe with the tweet ids in twitter_archive-enhanced.csv
tweet_ids = feed.tweet_id

# %%
# retrieve the full JSON for the status of each id in twitter-archive-enhanced.csv
# This script takes over 35 minutes to run
# load tweets stautus json file after gathering 
tweet_status = pd.read_json('tweet_json.txt', lines = True,encoding='utf-8')
failed_id = []
with open('tweet_json.txt', 'w', encoding='UTF-8') as json_file:
    for id_ in tweet_ids:
        try:
            tweet = api.get_status(id_)
            tweet = tweet._json
            json.dump(tweet, json_file)
            json_file.write('\n')
        except:
            print('Failed retrieving tweet with id ',id_)
            failed_id.append(id_)
# Out:
# Failed retrieving tweet with id  892420643555336193
# Failed retrieving tweet with id  892177421306343426
# Failed retrieving tweet with id  891815181378084864
# Failed retrieving tweet with id  891689557279858688
# Failed retrieving tweet with id  891327558926688256
# Failed retrieving tweet with id  891087950875897856
# Failed retrieving tweet with id  890971913173991426
# Failed retrieving tweet with id  890729181411237888
# Failed retrieving tweet with id  890609185150312448
# Failed retrieving tweet with id  890240255349198849
# Failed retrieving tweet with id  890006608113172480
# Failed retrieving tweet with id  889880896479866881
# Failed retrieving tweet with id  889665388333682689
# Failed retrieving tweet with id  889638837579907072
# Failed retrieving tweet with id  889531135344209921
# Failed retrieving tweet with id  889278841981685760
# Failed retrieving tweet with id  888917238123831296
# Failed retrieving tweet with id  888804989199671297
# Failed retrieving tweet with id  888554962724278272
# Failed retrieving tweet with id  888202515573088257
# Failed retrieving tweet with id  888078434458587136
# Failed retrieving tweet with id  887705289381826560
# Failed retrieving tweet with id  887517139158093824
# Failed retrieving tweet with id  887473957103951883
# Failed retrieving tweet with id  887343217045368832
# Failed retrieving tweet with id  887101392804085760
# Failed retrieving tweet with id  886983233522544640
# Failed retrieving tweet with id  886736880519319552
# Failed retrieving tweet with id  886680336477933568
# Failed retrieving tweet with id  886366144734445568
# Failed retrieving tweet with id  886267009285017600
# Failed retrieving tweet with id  886258384151887873
# Failed retrieving tweet with id  886054160059072513
# Failed retrieving tweet with id  885984800019947520
# Failed retrieving tweet with id  885528943205470208
# Failed retrieving tweet with id  885518971528720385
# Failed retrieving tweet with id  885311592912609280
# Failed retrieving tweet with id  885167619883638784
# Failed retrieving tweet with id  884925521741709313
# Failed retrieving tweet with id  884876753390489601
# Failed retrieving tweet with id  884562892145688576
# Failed retrieving tweet with id  884441805382717440
# Failed retrieving tweet with id  884247878851493888
# Failed retrieving tweet with id  884162670584377345
# Failed retrieving tweet with id  883838122936631299
# Failed retrieving tweet with id  883482846933004288
# Failed retrieving tweet with id  883360690899218434
# Failed retrieving tweet with id  883117836046086144
# Failed retrieving tweet with id  882992080364220416
# Failed retrieving tweet with id  882762694511734784
# Failed retrieving tweet with id  882627270321602560
# Failed retrieving tweet with id  882268110199369728
# Failed retrieving tweet with id  882045870035918850
# Failed retrieving tweet with id  881906580714921986
# Failed retrieving tweet with id  881666595344535552
# Failed retrieving tweet with id  881633300179243008
# Failed retrieving tweet with id  881536004380872706
# Failed retrieving tweet with id  881268444196462592
# Failed retrieving tweet with id  880935762899988482
# Failed retrieving tweet with id  880872448815771648
# Failed retrieving tweet with id  880465832366813184
# Failed retrieving tweet with id  880221127280381952
# Failed retrieving tweet with id  880095782870896641
# Failed retrieving tweet with id  879862464715927552
# Failed retrieving tweet with id  879674319642796034
# Failed retrieving tweet with id  879492040517615616
# Failed retrieving tweet with id  879415818425184262
# Failed retrieving tweet with id  879376492567855104
# Failed retrieving tweet with id  879130579576475649
# Failed retrieving tweet with id  879050749262655488
# Failed retrieving tweet with id  879008229531029506
# Failed retrieving tweet with id  878776093423087618
# Failed retrieving tweet with id  878604707211726852
# Failed retrieving tweet with id  878404777348136964
# Failed retrieving tweet with id  878316110768087041
# Failed retrieving tweet with id  878281511006478336
# Failed retrieving tweet with id  878057613040115712
# Failed retrieving tweet with id  877736472329191424
# Failed retrieving tweet with id  877611172832227328
# Failed retrieving tweet with id  877556246731214848
# Failed retrieving tweet with id  877316821321428993
# Failed retrieving tweet with id  877201837425926144
# Failed retrieving tweet with id  876838120628539392
# Failed retrieving tweet with id  876537666061221889
# Failed retrieving tweet with id  876484053909872640
# Failed retrieving tweet with id  876120275196170240
# Failed retrieving tweet with id  875747767867523072
# Failed retrieving tweet with id  875144289856114688
# Failed retrieving tweet with id  875097192612077568
# Failed retrieving tweet with id  875021211251597312
# Failed retrieving tweet with id  874680097055178752
# Failed retrieving tweet with id  874434818259525634
# Failed retrieving tweet with id  874296783580663808
# Failed retrieving tweet with id  874057562936811520
# Failed retrieving tweet with id  874012996292530176
# Failed retrieving tweet with id  873697596434513921
# Failed retrieving tweet with id  873580283840344065
# Failed retrieving tweet with id  873337748698140672
# Failed retrieving tweet with id  873213775632977920
# Failed retrieving tweet with id  872967104147763200
# Failed retrieving tweet with id  872820683541237760
# Failed retrieving tweet with id  872668790621863937
# Failed retrieving tweet with id  872620804844003328
# Failed retrieving tweet with id  872486979161796608
# Failed retrieving tweet with id  872261713294495745
# Failed retrieving tweet with id  872122724285648897
# Failed retrieving tweet with id  871879754684805121
# Failed retrieving tweet with id  871762521631449091
# Failed retrieving tweet with id  871515927908634625
# Failed retrieving tweet with id  871166179821445120
# Failed retrieving tweet with id  871102520638267392
# Failed retrieving tweet with id  871032628920680449
# Failed retrieving tweet with id  870804317367881728
# Failed retrieving tweet with id  870726314365509632
# Failed retrieving tweet with id  870656317836468226
# Failed retrieving tweet with id  870374049280663552
# Failed retrieving tweet with id  870308999962521604
# Failed retrieving tweet with id  870063196459192321
# Failed retrieving tweet with id  869988702071779329
# Failed retrieving tweet with id  869772420881756160
# Failed retrieving tweet with id  869702957897576449
# Failed retrieving tweet with id  869596645499047938
# Failed retrieving tweet with id  869227993411051520
# Failed retrieving tweet with id  868880397819494401
# Failed retrieving tweet with id  868639477480148993
# Failed retrieving tweet with id  868622495443632128
# Failed retrieving tweet with id  868552278524837888
# Failed retrieving tweet with id  867900495410671616
# Failed retrieving tweet with id  867774946302451713
# Failed retrieving tweet with id  867421006826221569
# Failed retrieving tweet with id  867072653475098625
# Failed retrieving tweet with id  867051520902168576
# Failed retrieving tweet with id  866816280283807744
# Failed retrieving tweet with id  866720684873056260
# Failed retrieving tweet with id  866686824827068416
# Failed retrieving tweet with id  866450705531457537
# Failed retrieving tweet with id  866334964761202691
# Failed retrieving tweet with id  866094527597207552
# Failed retrieving tweet with id  865718153858494464
# Failed retrieving tweet with id  865359393868664832
# Failed retrieving tweet with id  865006731092295680
# Failed retrieving tweet with id  864873206498414592
# Failed retrieving tweet with id  864279568663928832
# Failed retrieving tweet with id  864197398364647424
# Failed retrieving tweet with id  863907417377173506
# Failed retrieving tweet with id  863553081350529029
# Failed retrieving tweet with id  863471782782697472
# Failed retrieving tweet with id  863432100342583297
# Failed retrieving tweet with id  863427515083354112
# Failed retrieving tweet with id  863079547188785154
# Failed retrieving tweet with id  863062471531167744
# Failed retrieving tweet with id  862831371563274240
# Failed retrieving tweet with id  862722525377298433
# Failed retrieving tweet with id  862457590147678208
# Failed retrieving tweet with id  862096992088072192
# Failed retrieving tweet with id  861769973181624320
# Failed retrieving tweet with id  861383897657036800
# Failed retrieving tweet with id  861288531465048066
# Failed retrieving tweet with id  861005113778896900
# Failed retrieving tweet with id  860981674716409858
# Failed retrieving tweet with id  860924035999428608
# Failed retrieving tweet with id  860563773140209665
# Failed retrieving tweet with id  860524505164394496
# Failed retrieving tweet with id  860276583193509888
# Failed retrieving tweet with id  860184849394610176
# Failed retrieving tweet with id  860177593139703809
# Failed retrieving tweet with id  859924526012018688
# Failed retrieving tweet with id  859851578198683649
# Failed retrieving tweet with id  859607811541651456
# Failed retrieving tweet with id  859196978902773760
# Failed retrieving tweet with id  859074603037188101
# Failed retrieving tweet with id  858860390427611136
# Failed retrieving tweet with id  858843525470990336
# Failed retrieving tweet with id  858471635011153920
# Failed retrieving tweet with id  858107933456039936
# Failed retrieving tweet with id  857989990357356544
# Failed retrieving tweet with id  857746408056729600
# Failed retrieving tweet with id  857393404942143489
# Failed retrieving tweet with id  857263160327368704
# Failed retrieving tweet with id  857214891891077121
# Failed retrieving tweet with id  857062103051644929
# Failed retrieving tweet with id  857029823797047296
# Failed retrieving tweet with id  856602993587888130
# Failed retrieving tweet with id  856543823941562368
# Failed retrieving tweet with id  856526610513747968
# Failed retrieving tweet with id  856330835276025856
# Failed retrieving tweet with id  856288084350160898
# Failed retrieving tweet with id  856282028240666624
# Failed retrieving tweet with id  855862651834028034
# Failed retrieving tweet with id  855860136149123072
# Failed retrieving tweet with id  855857698524602368
# Failed retrieving tweet with id  855851453814013952
# Failed retrieving tweet with id  855818117272018944
# Failed retrieving tweet with id  855459453768019968
# Failed retrieving tweet with id  855245323840757760
# Failed retrieving tweet with id  855138241867124737
# Failed retrieving tweet with id  854732716440526848
# Failed retrieving tweet with id  854482394044301312
# Failed retrieving tweet with id  854365224396361728
# Failed retrieving tweet with id  854120357044912130
# Failed retrieving tweet with id  854010172552949760
# Failed retrieving tweet with id  853760880890318849
# Failed retrieving tweet with id  853639147608842240
# Failed retrieving tweet with id  853299958564483072
# Failed retrieving tweet with id  852936405516943360
# Failed retrieving tweet with id  852912242202992640
# Failed retrieving tweet with id  852672615818899456
# Failed retrieving tweet with id  852553447878664193
# Failed retrieving tweet with id  852311364735569921
# Failed retrieving tweet with id  852226086759018497
# Failed retrieving tweet with id  852189679701164033
# Failed retrieving tweet with id  851953902622658560
# Failed retrieving tweet with id  851861385021730816
# Failed retrieving tweet with id  851591660324737024
# Failed retrieving tweet with id  851464819735769094
# Failed retrieving tweet with id  851224888060895234
# Failed retrieving tweet with id  850753642995093505
# Failed retrieving tweet with id  850380195714523136
# Failed retrieving tweet with id  850333567704068097
# Failed retrieving tweet with id  850145622816686080
# Failed retrieving tweet with id  850019790995546112
# Failed retrieving tweet with id  849776966551130114
# Failed retrieving tweet with id  849668094696017920
# Failed retrieving tweet with id  849412302885593088
# Failed retrieving tweet with id  849336543269576704
# Failed retrieving tweet with id  849051919805034497
# Failed retrieving tweet with id  848690551926992896
# Failed retrieving tweet with id  848324959059550208
# Failed retrieving tweet with id  848213670039564288
# Failed retrieving tweet with id  848212111729840128
# Failed retrieving tweet with id  847978865427394560
# Failed retrieving tweet with id  847971574464610304
# Failed retrieving tweet with id  847962785489326080
# Failed retrieving tweet with id  847842811428974592
# Failed retrieving tweet with id  847617282490613760
# Failed retrieving tweet with id  847606175596138505
# Failed retrieving tweet with id  847251039262605312
# Failed retrieving tweet with id  847157206088847362
# Failed retrieving tweet with id  847116187444137987
# Failed retrieving tweet with id  846874817362120707
# Failed retrieving tweet with id  846514051647705089
# Failed retrieving tweet with id  846505985330044928
# Failed retrieving tweet with id  846153765933735936
# Failed retrieving tweet with id  846139713627017216
# Failed retrieving tweet with id  846042936437604353
# Failed retrieving tweet with id  845812042753855489
# Failed retrieving tweet with id  845677943972139009
# Failed retrieving tweet with id  845459076796616705
# Failed retrieving tweet with id  845397057150107648
# Failed retrieving tweet with id  845306882940190720
# Failed retrieving tweet with id  845098359547420673
# Failed retrieving tweet with id  844979544864018432
# Failed retrieving tweet with id  844973813909606400
# Failed retrieving tweet with id  844704788403113984
# Failed retrieving tweet with id  844580511645339650
# Failed retrieving tweet with id  844223788422217728
# Failed retrieving tweet with id  843981021012017153
# Failed retrieving tweet with id  843856843873095681
# Failed retrieving tweet with id  843604394117681152
# Failed retrieving tweet with id  843235543001513987
# Failed retrieving tweet with id  842892208864923648
# Failed retrieving tweet with id  842846295480000512
# Failed retrieving tweet with id  842765311967449089
# Failed retrieving tweet with id  842535590457499648
# Failed retrieving tweet with id  842163532590374912
# Failed retrieving tweet with id  842115215311396866
# Failed retrieving tweet with id  841833993020538882
# Failed retrieving tweet with id  841680585030541313
# Failed retrieving tweet with id  841439858740625411
# Failed retrieving tweet with id  841320156043304961
# Failed retrieving tweet with id  841314665196081154
# Failed retrieving tweet with id  841077006473256960
# Failed retrieving tweet with id  840761248237133825
# Failed retrieving tweet with id  840728873075638272
# Failed retrieving tweet with id  840698636975636481
# Failed retrieving tweet with id  840696689258311684
# Failed retrieving tweet with id  840632337062862849
# Failed retrieving tweet with id  840370681858686976
# Failed retrieving tweet with id  840268004936019968
# Failed retrieving tweet with id  839990271299457024
# Failed retrieving tweet with id  839549326359670784
# Failed retrieving tweet with id  839290600511926273
# Failed retrieving tweet with id  839239871831150596
# Failed retrieving tweet with id  838952994649550848
# Failed retrieving tweet with id  838921590096166913
# Failed retrieving tweet with id  838916489579200512
# Failed retrieving tweet with id  838831947270979586
# Failed retrieving tweet with id  838561493054533637
# Failed retrieving tweet with id  838476387338051585
# Failed retrieving tweet with id  838201503651401729
# Failed retrieving tweet with id  838150277551247360
# Failed retrieving tweet with id  838085839343206401
# Failed retrieving tweet with id  838083903487373313
# Failed retrieving tweet with id  837820167694528512
# Failed retrieving tweet with id  837482249356513284
# Failed retrieving tweet with id  837471256429613056
# Failed retrieving tweet with id  837366284874571778
# Failed retrieving tweet with id  837110210464448512
# Failed retrieving tweet with id  837012587749474308
# Failed retrieving tweet with id  836989968035819520
# Failed retrieving tweet with id  836753516572119041
# Failed retrieving tweet with id  836677758902222849
# Failed retrieving tweet with id  836648853927522308
# Failed retrieving tweet with id  836397794269200385
# Failed retrieving tweet with id  836380477523124226
# Failed retrieving tweet with id  836260088725786625
# Failed retrieving tweet with id  836001077879255040
# Failed retrieving tweet with id  835685285446955009
# Failed retrieving tweet with id  835574547218894849
# Failed retrieving tweet with id  835536468978302976
# Failed retrieving tweet with id  835309094223372289
# Failed retrieving tweet with id  835297930240217089
# Failed retrieving tweet with id  835264098648616962
# Failed retrieving tweet with id  835246439529840640
# Failed retrieving tweet with id  835172783151792128
# Failed retrieving tweet with id  835152434251116546
# Failed retrieving tweet with id  834931633769889797
# Failed retrieving tweet with id  834786237630337024
# Failed retrieving tweet with id  834574053763584002
# Failed retrieving tweet with id  834477809192075265
# Failed retrieving tweet with id  834458053273591808
# Failed retrieving tweet with id  834209720923721728
# Failed retrieving tweet with id  834167344700198914
# Failed retrieving tweet with id  834089966724603904
# Failed retrieving tweet with id  834086379323871233
# Failed retrieving tweet with id  833863086058651648
# Failed retrieving tweet with id  833826103416520705
# Failed retrieving tweet with id  833732339549220864
# Failed retrieving tweet with id  833722901757046785
# Failed retrieving tweet with id  833479644947025920
# Failed retrieving tweet with id  833124694597443584
# Failed retrieving tweet with id  832998151111966721
# Failed retrieving tweet with id  832769181346996225
# Failed retrieving tweet with id  832757312314028032
# Failed retrieving tweet with id  832682457690300417
# Failed retrieving tweet with id  832645525019123713
# Failed retrieving tweet with id  832636094638288896
# Failed retrieving tweet with id  832397543355072512
# Failed retrieving tweet with id  832369877331693569
# Failed retrieving tweet with id  832273440279240704
# Failed retrieving tweet with id  832215909146226688
# Failed retrieving tweet with id  832215726631055365
# Failed retrieving tweet with id  832088576586297345
# Failed retrieving tweet with id  832040443403784192
# Failed retrieving tweet with id  832032802820481025
# Failed retrieving tweet with id  831939777352105988
# Failed retrieving tweet with id  831926988323639298
# Failed retrieving tweet with id  831911600680497154
# Failed retrieving tweet with id  831670449226514432
# Failed retrieving tweet with id  831650051525054464
# Failed retrieving tweet with id  831552930092285952
# Failed retrieving tweet with id  831322785565769729
# Failed retrieving tweet with id  831315979191906304
# Failed retrieving tweet with id  831309418084069378
# Failed retrieving tweet with id  831262627380748289
# Failed retrieving tweet with id  830956169170665475
# Failed retrieving tweet with id  830583320585068544
# Failed retrieving tweet with id  830173239259324417
# Failed retrieving tweet with id  830097400375152640
# Failed retrieving tweet with id  829878982036299777
# Failed retrieving tweet with id  829861396166877184
# Failed retrieving tweet with id  829501995190984704
# Failed retrieving tweet with id  829449946868879360
# Failed retrieving tweet with id  829374341691346946
# Failed retrieving tweet with id  829141528400556032
# Failed retrieving tweet with id  829011960981237760
# Failed retrieving tweet with id  828801551087042563
# Failed retrieving tweet with id  828770345708580865
# Failed retrieving tweet with id  828708714936930305
# Failed retrieving tweet with id  828650029636317184
# Failed retrieving tweet with id  828409743546925057
# Failed retrieving tweet with id  828408677031882754
# Failed retrieving tweet with id  828381636999917570
# Failed retrieving tweet with id  828376505180889089
# Failed retrieving tweet with id  828372645993398273
# Failed retrieving tweet with id  828361771580813312
# Failed retrieving tweet with id  828046555563323392
# Failed retrieving tweet with id  828011680017821696
# Failed retrieving tweet with id  827933404142436356
# Failed retrieving tweet with id  827653905312006145
# Failed retrieving tweet with id  827600520311402496
# Failed retrieving tweet with id  827324948884643840
# Failed retrieving tweet with id  827228250799742977
# Failed retrieving tweet with id  827199976799354881
# Failed retrieving tweet with id  826958653328592898
# Failed retrieving tweet with id  826848821049180160
# Failed retrieving tweet with id  826615380357632002
# Failed retrieving tweet with id  826598799820865537
# Failed retrieving tweet with id  826598365270007810
# Failed retrieving tweet with id  826476773533745153
# Failed retrieving tweet with id  826240494070030336
# Failed retrieving tweet with id  826204788643753985
# Failed retrieving tweet with id  826115272272650244
# Failed retrieving tweet with id  825876512159186944
# Failed retrieving tweet with id  825829644528148480
# Failed retrieving tweet with id  825535076884762624
# Failed retrieving tweet with id  825147591692263424
# Failed retrieving tweet with id  825120256414846976
# Failed retrieving tweet with id  825026590719483904
# Failed retrieving tweet with id  824796380199809024
# Failed retrieving tweet with id  824775126675836928
# Failed retrieving tweet with id  824663926340194305
# Failed retrieving tweet with id  824325613288833024
# Failed retrieving tweet with id  824297048279236611
# Failed retrieving tweet with id  824025158776213504
# Failed retrieving tweet with id  823939628516474880
# Failed retrieving tweet with id  823719002937630720
# Failed retrieving tweet with id  823699002998870016
# Failed retrieving tweet with id  823581115634085888
# Failed retrieving tweet with id  823333489516937216
# Failed retrieving tweet with id  823322678127919110
# Failed retrieving tweet with id  823269594223824897
# Failed retrieving tweet with id  822975315408461824
# Failed retrieving tweet with id  822872901745569793
# Failed retrieving tweet with id  822859134160621569
# Failed retrieving tweet with id  822647212903690241
# Failed retrieving tweet with id  822610361945911296
# Failed retrieving tweet with id  822489057087389700
# Failed retrieving tweet with id  822462944365645825
# Failed retrieving tweet with id  822244816520155136
# Failed retrieving tweet with id  822163064745328640
# Failed retrieving tweet with id  821886076407029760
# Failed retrieving tweet with id  821813639212650496
# Failed retrieving tweet with id  821765923262631936
# Failed retrieving tweet with id  821522889702862852
# Failed retrieving tweet with id  821421320206483457
# Failed retrieving tweet with id  821407182352777218
# Failed retrieving tweet with id  821153421864615936
# Failed retrieving tweet with id  821149554670182400
# Failed retrieving tweet with id  821107785811234820
# Failed retrieving tweet with id  821044531881721856
# Failed retrieving tweet with id  820837357901512704
# Failed retrieving tweet with id  820749716845686786
# Failed retrieving tweet with id  820690176645140481
# Failed retrieving tweet with id  820494788566847489
# Failed retrieving tweet with id  820446719150292993
# Failed retrieving tweet with id  820314633777061888
# Failed retrieving tweet with id  820078625395449857
# Failed retrieving tweet with id  820013781606658049
# Failed retrieving tweet with id  819952236453363712
# Failed retrieving tweet with id  819924195358416896
# Failed retrieving tweet with id  819711362133872643
# Failed retrieving tweet with id  819588359383371776
# Failed retrieving tweet with id  819347104292290561
# Failed retrieving tweet with id  819238181065359361
# Failed retrieving tweet with id  819227688460238848
# Failed retrieving tweet with id  819015337530290176
# Failed retrieving tweet with id  819015331746349057
# Failed retrieving tweet with id  819006400881917954
# Failed retrieving tweet with id  819004803107983360
# Failed retrieving tweet with id  818646164899774465
# Failed retrieving tweet with id  818627210458333184
# Failed retrieving tweet with id  818614493328580609
# Failed retrieving tweet with id  818588835076603904
# Failed retrieving tweet with id  818536468981415936
# Failed retrieving tweet with id  818307523543449600
# Failed retrieving tweet with id  818259473185828864
# Failed retrieving tweet with id  818145370475810820
# Failed retrieving tweet with id  817908911860748288
# Failed retrieving tweet with id  817827839487737858
# Failed retrieving tweet with id  817777686764523521
# Failed retrieving tweet with id  817536400337801217
# Failed retrieving tweet with id  817502432452313088
# Failed retrieving tweet with id  817423860136083457
# Failed retrieving tweet with id  817415592588222464
# Failed retrieving tweet with id  817181837579653120
# Failed retrieving tweet with id  817171292965273600
# Failed retrieving tweet with id  817120970343411712
# Failed retrieving tweet with id  817056546584727552
# Failed retrieving tweet with id  816829038950027264
# Failed retrieving tweet with id  816816676327063552
# Failed retrieving tweet with id  816697700272001025
# Failed retrieving tweet with id  816450570814898180
# Failed retrieving tweet with id  816336735214911488
# Failed retrieving tweet with id  816091915477250048
# Failed retrieving tweet with id  816062466425819140
# Failed retrieving tweet with id  816014286006976512
# Failed retrieving tweet with id  815990720817401858
# Failed retrieving tweet with id  815966073409433600
# Failed retrieving tweet with id  815745968457060357
# Failed retrieving tweet with id  815736392542261248
# Failed retrieving tweet with id  815639385530101762
# Failed retrieving tweet with id  815390420867969024
# Failed retrieving tweet with id  814986499976527872
# Failed retrieving tweet with id  814638523311648768
# Failed retrieving tweet with id  814578408554463233
# Failed retrieving tweet with id  814530161257443328
# Failed retrieving tweet with id  814153002265309185
# Failed retrieving tweet with id  813944609378369540
# Failed retrieving tweet with id  813910438903693312
# Failed retrieving tweet with id  813812741911748608
# Failed retrieving tweet with id  813800681631023104
# Failed retrieving tweet with id  813217897535406080
# Failed retrieving tweet with id  813202720496779264
# Failed retrieving tweet with id  813187593374461952
# Failed retrieving tweet with id  813172488309972993
# Failed retrieving tweet with id  813157409116065792
# Failed retrieving tweet with id  813142292504645637
# Failed retrieving tweet with id  813130366689148928
# Failed retrieving tweet with id  813127251579564032
# Failed retrieving tweet with id  813112105746448384
# Failed retrieving tweet with id  813096984823349248
# Failed retrieving tweet with id  813081950185472002
# Failed retrieving tweet with id  813066809284972545
# Failed retrieving tweet with id  813051746834595840
# Failed retrieving tweet with id  812781120811126785
# Failed retrieving tweet with id  812747805718642688
# Failed retrieving tweet with id  812709060537683968
# Failed retrieving tweet with id  812503143955202048
# Failed retrieving tweet with id  812466873996607488
# Failed retrieving tweet with id  812372279581671427
# Failed retrieving tweet with id  811985624773361665
# Failed retrieving tweet with id  811744202451197953
# Failed retrieving tweet with id  811647686436880384
# Failed retrieving tweet with id  811627233043480576
# Failed retrieving tweet with id  811386762094317568
# Failed retrieving tweet with id  810984652412424192
# Failed retrieving tweet with id  810896069567610880
# Failed retrieving tweet with id  810657578271330305
# Failed retrieving tweet with id  810284430598270976
# Failed retrieving tweet with id  810254108431155201
# Failed retrieving tweet with id  809920764300447744
# Failed retrieving tweet with id  809808892968534016
# Failed retrieving tweet with id  809448704142938112
# Failed retrieving tweet with id  809220051211603969
# Failed retrieving tweet with id  809084759137812480
# Failed retrieving tweet with id  808838249661788160
# Failed retrieving tweet with id  808733504066486276
# Failed retrieving tweet with id  808501579447930884
# Failed retrieving tweet with id  808344865868283904
# Failed retrieving tweet with id  808134635716833280
# Failed retrieving tweet with id  808106460588765185
# Failed retrieving tweet with id  808001312164028416
# Failed retrieving tweet with id  807621403335917568
# Failed retrieving tweet with id  807106840509214720
# Failed retrieving tweet with id  807059379405148160
# Failed retrieving tweet with id  807010152071229440
# Failed retrieving tweet with id  806629075125202948
# Failed retrieving tweet with id  806620845233815552
# Failed retrieving tweet with id  806576416489959424
# Failed retrieving tweet with id  806542213899489280
# Failed retrieving tweet with id  806242860592926720
# Failed retrieving tweet with id  806219024703037440
# Failed retrieving tweet with id  805958939288408065
# Failed retrieving tweet with id  805932879469572096
# Failed retrieving tweet with id  805826884734976000
# Failed retrieving tweet with id  805823200554876929
# Failed retrieving tweet with id  805520635690676224
# Failed retrieving tweet with id  805487436403003392
# Failed retrieving tweet with id  805207613751304193
# Failed retrieving tweet with id  804738756058218496
# Failed retrieving tweet with id  804475857670639616
# Failed retrieving tweet with id  804413760345620481
# Failed retrieving tweet with id  804026241225523202
# Failed retrieving tweet with id  803773340896923648
# Failed retrieving tweet with id  803692223237865472
# Failed retrieving tweet with id  803638050916102144
# Failed retrieving tweet with id  803380650405482500
# Failed retrieving tweet with id  803321560782307329
# Failed retrieving tweet with id  803276597545603072
# Failed retrieving tweet with id  802952499103731712
# Failed retrieving tweet with id  802624713319034886
# Failed retrieving tweet with id  802600418706604034
# Failed retrieving tweet with id  802572683846291456
# Failed retrieving tweet with id  802323869084381190
# Failed retrieving tweet with id  802265048156610565
# Failed retrieving tweet with id  802247111496568832
# Failed retrieving tweet with id  802239329049477120
# Failed retrieving tweet with id  802185808107208704
# Failed retrieving tweet with id  801958328846974976
# Failed retrieving tweet with id  801854953262350336
# Failed retrieving tweet with id  801538201127157760
# Failed retrieving tweet with id  801285448605831168
# Failed retrieving tweet with id  801167903437357056
# Failed retrieving tweet with id  801127390143516673
# Failed retrieving tweet with id  801115127852503040
# Failed retrieving tweet with id  800859414831898624
# Failed retrieving tweet with id  800855607700029440
# Failed retrieving tweet with id  800751577355128832
# Failed retrieving tweet with id  800513324630806528
# Failed retrieving tweet with id  800459316964663297
# Failed retrieving tweet with id  800443802682937345
# Failed retrieving tweet with id  800388270626521089
# Failed retrieving tweet with id  800188575492947969
# Failed retrieving tweet with id  800141422401830912
# Failed retrieving tweet with id  800018252395122689
# Failed retrieving tweet with id  799774291445383169
# Failed retrieving tweet with id  799757965289017345
# Failed retrieving tweet with id  799422933579902976
# Failed retrieving tweet with id  799308762079035393
# Failed retrieving tweet with id  799297110730567681
# Failed retrieving tweet with id  799063482566066176
# Failed retrieving tweet with id  798933969379225600
# Failed retrieving tweet with id  798925684722855936
# Failed retrieving tweet with id  798705661114773508
# Failed retrieving tweet with id  798701998996647937
# Failed retrieving tweet with id  798697898615730177
# Failed retrieving tweet with id  798694562394996736
# Failed retrieving tweet with id  798686750113755136
# Failed retrieving tweet with id  798682547630837760
# Failed retrieving tweet with id  798673117451325440
# Failed retrieving tweet with id  798665375516884993
# Failed retrieving tweet with id  798644042770751489
# Failed retrieving tweet with id  798628517273620480
# Failed retrieving tweet with id  798585098161549313
# Failed retrieving tweet with id  798576900688019456
# Failed retrieving tweet with id  798340744599797760
# Failed retrieving tweet with id  798209839306514432
# Failed retrieving tweet with id  797971864723324932
# Failed retrieving tweet with id  797545162159308800
# Failed retrieving tweet with id  797236660651966464
# Failed retrieving tweet with id  797165961484890113
# Failed retrieving tweet with id  796904159865868288
# Failed retrieving tweet with id  796865951799083009
# Failed retrieving tweet with id  796759840936919040
# Failed retrieving tweet with id  796563435802726400
# Failed retrieving tweet with id  796484825502875648
# Failed retrieving tweet with id  796387464403357696
# Failed retrieving tweet with id  796177847564038144
# Failed retrieving tweet with id  796149749086875649
# Failed retrieving tweet with id  796125600683540480
# Failed retrieving tweet with id  796116448414461957
# Failed retrieving tweet with id  796080075804475393
# Failed retrieving tweet with id  796031486298386433
# Failed retrieving tweet with id  795464331001561088
# Failed retrieving tweet with id  795400264262053889
# Failed retrieving tweet with id  795076730285391872
# Failed retrieving tweet with id  794983741416415232
# Failed retrieving tweet with id  794926597468000259
# Failed retrieving tweet with id  794355576146903043
# Failed retrieving tweet with id  794332329137291264
# Failed retrieving tweet with id  794205286408003585
# Failed retrieving tweet with id  793962221541933056
# Failed retrieving tweet with id  793845145112371200
# Failed retrieving tweet with id  793614319594401792
# Failed retrieving tweet with id  793601777308463104
# Failed retrieving tweet with id  793500921481273345
# Failed retrieving tweet with id  793286476301799424
# Failed retrieving tweet with id  793271401113350145
# Failed retrieving tweet with id  793256262322548741
# Failed retrieving tweet with id  793241302385262592
# Failed retrieving tweet with id  793226087023144960
# Failed retrieving tweet with id  793210959003287553
# Failed retrieving tweet with id  793195938047070209
# Failed retrieving tweet with id  793180763617361921
# Failed retrieving tweet with id  793165685325201412
# Failed retrieving tweet with id  793150605191548928
# Failed retrieving tweet with id  793135492858580992
# Failed retrieving tweet with id  793120401413079041
# Failed retrieving tweet with id  792913359805018113
# Failed retrieving tweet with id  792883833364439040
# Failed retrieving tweet with id  792773781206999040
# Failed retrieving tweet with id  792394556390137856
# Failed retrieving tweet with id  792050063153438720
# Failed retrieving tweet with id  791821351946420224
# Failed retrieving tweet with id  791784077045166082
# Failed retrieving tweet with id  791780927877898241
# Failed retrieving tweet with id  791774931465953280
# Failed retrieving tweet with id  791672322847637504
# Failed retrieving tweet with id  791406955684368384
# Failed retrieving tweet with id  791312159183634433
# Failed retrieving tweet with id  791026214425268224
# Failed retrieving tweet with id  790987426131050500
# Failed retrieving tweet with id  790946055508652032
# Failed retrieving tweet with id  790723298204217344
# Failed retrieving tweet with id  790698755171364864
# Failed retrieving tweet with id  790581949425475584
# Failed retrieving tweet with id  790337589677002753
# Failed retrieving tweet with id  790277117346975746
# Failed retrieving tweet with id  790227638568808452
# Failed retrieving tweet with id  789986466051088384
# Failed retrieving tweet with id  789960241177853952
# Failed retrieving tweet with id  789903600034189313
# Failed retrieving tweet with id  789628658055020548
# Failed retrieving tweet with id  789599242079838210
# Failed retrieving tweet with id  789530877013393408
# Failed retrieving tweet with id  789314372632018944
# Failed retrieving tweet with id  789280767834746880
# Failed retrieving tweet with id  789268448748703744
# Failed retrieving tweet with id  789137962068021249
# Failed retrieving tweet with id  788908386943430656
# Failed retrieving tweet with id  788765914992902144
# Failed retrieving tweet with id  788552643979468800
# Failed retrieving tweet with id  788412144018661376
# Failed retrieving tweet with id  788178268662984705
# Failed retrieving tweet with id  788150585577050112
# Failed retrieving tweet with id  788070120937619456
# Failed retrieving tweet with id  788039637453406209
# Failed retrieving tweet with id  787810552592695296
# Failed retrieving tweet with id  787717603741622272
# Failed retrieving tweet with id  787397959788929025
# Failed retrieving tweet with id  787322443945877504
# Failed retrieving tweet with id  787111942498508800
# Failed retrieving tweet with id  786963064373534720
# Failed retrieving tweet with id  786729988674449408
# Failed retrieving tweet with id  786709082849828864
# Failed retrieving tweet with id  786664955043049472
# Failed retrieving tweet with id  786595970293370880
# Failed retrieving tweet with id  786363235746385920
# Failed retrieving tweet with id  786286427768250368
# Failed retrieving tweet with id  786233965241827333
# Failed retrieving tweet with id  786051337297522688
# Failed retrieving tweet with id  786036967502913536
# Failed retrieving tweet with id  785927819176054784
# Failed retrieving tweet with id  785872687017132033
# Failed retrieving tweet with id  785639753186217984
# Failed retrieving tweet with id  785533386513321988
# Failed retrieving tweet with id  785515384317313025
# Failed retrieving tweet with id  785264754247995392
# Failed retrieving tweet with id  785170936622350336
# Failed retrieving tweet with id  784826020293709826
# Failed retrieving tweet with id  784517518371221505
# Failed retrieving tweet with id  784431430411685888
# Failed retrieving tweet with id  784183165795655680
# Failed retrieving tweet with id  784057939640352768
# Failed retrieving tweet with id  783839966405230592
# Failed retrieving tweet with id  783821107061198850
# Failed retrieving tweet with id  783695101801398276
# Failed retrieving tweet with id  783466772167098368
# Failed retrieving tweet with id  783391753726550016
# Failed retrieving tweet with id  783347506784731136
# Failed retrieving tweet with id  783334639985389568
# Failed retrieving tweet with id  783085703974514689
# Failed retrieving tweet with id  782969140009107456
# Failed retrieving tweet with id  782747134529531904
# Failed retrieving tweet with id  782722598790725632
# Failed retrieving tweet with id  782598640137187329
# Failed retrieving tweet with id  782305867769217024
# Failed retrieving tweet with id  782021823840026624
# Failed retrieving tweet with id  781955203444699136
# Failed retrieving tweet with id  781661882474196992
# Failed retrieving tweet with id  781655249211752448
# Failed retrieving tweet with id  781524693396357120
# Failed retrieving tweet with id  781308096455073793
# Failed retrieving tweet with id  781251288990355457
# Failed retrieving tweet with id  781163403222056960
# Failed retrieving tweet with id  780931614150983680
# Failed retrieving tweet with id  780858289093574656
# Failed retrieving tweet with id  780800785462489090
# Failed retrieving tweet with id  780601303617732608
# Failed retrieving tweet with id  780543529827336192
# Failed retrieving tweet with id  780496263422808064
# Failed retrieving tweet with id  780476555013349377
# Failed retrieving tweet with id  780459368902959104
# Failed retrieving tweet with id  780192070812196864
# Failed retrieving tweet with id  780092040432480260
# Failed retrieving tweet with id  780074436359819264
# Failed retrieving tweet with id  779834332596887552
# Failed retrieving tweet with id  779377524342161408
# Failed retrieving tweet with id  779124354206535695
# Failed retrieving tweet with id  779123168116150273
# Failed retrieving tweet with id  779056095788752897
# Failed retrieving tweet with id  778990705243029504
# Failed retrieving tweet with id  778774459159379968
# Failed retrieving tweet with id  778764940568104960
# Failed retrieving tweet with id  778748913645780993
# Failed retrieving tweet with id  778650543019483137
# Failed retrieving tweet with id  778624900596654080
# Failed retrieving tweet with id  778408200802557953
# Failed retrieving tweet with id  778396591732486144
# Failed retrieving tweet with id  778383385161035776
# Failed retrieving tweet with id  778286810187399168
# Failed retrieving tweet with id  778039087836069888
# Failed retrieving tweet with id  778027034220126208
# Failed retrieving tweet with id  777953400541634568
# Failed retrieving tweet with id  777885040357281792
# Failed retrieving tweet with id  777684233540206592
# Failed retrieving tweet with id  777641927919427584
# Failed retrieving tweet with id  777621514455814149
# Failed retrieving tweet with id  777189768882946048
# Failed retrieving tweet with id  776819012571455488
# Failed retrieving tweet with id  776813020089548800
# Failed retrieving tweet with id  776477788987613185
# Failed retrieving tweet with id  776249906839351296
# Failed retrieving tweet with id  776218204058357768
# Failed retrieving tweet with id  776201521193218049
# Failed retrieving tweet with id  776113305656188928
# Failed retrieving tweet with id  776088319444877312
# Failed retrieving tweet with id  775898661951791106
# Failed retrieving tweet with id  775842724423557120
# Failed retrieving tweet with id  775733305207554048
# Failed retrieving tweet with id  775729183532220416
# Failed retrieving tweet with id  775364825476165632
# Failed retrieving tweet with id  775350846108426240
# Failed retrieving tweet with id  775096608509886464
# Failed retrieving tweet with id  775085132600442880
# Failed retrieving tweet with id  774757898236878852
# Failed retrieving tweet with id  774639387460112384
# Failed retrieving tweet with id  774314403806253056
# Failed retrieving tweet with id  773985732834758656
# Failed retrieving tweet with id  773922284943896577
# Failed retrieving tweet with id  773704687002451968
# Failed retrieving tweet with id  773670353721753600
# Failed retrieving tweet with id  773547596996571136
# Failed retrieving tweet with id  773336787167145985
# Failed retrieving tweet with id  773308824254029826
# Failed retrieving tweet with id  773247561583001600
# Failed retrieving tweet with id  773191612633579521
# Failed retrieving tweet with id  772877495989305348
# Failed retrieving tweet with id  772826264096874500
# Failed retrieving tweet with id  772615324260794368
# Failed retrieving tweet with id  772581559778025472
# Failed retrieving tweet with id  772193107915964416
# Failed retrieving tweet with id  772152991789019136
# Failed retrieving tweet with id  772117678702071809
# Failed retrieving tweet with id  772114945936949249
# Failed retrieving tweet with id  772102971039580160
# Failed retrieving tweet with id  771908950375665664
# Failed retrieving tweet with id  771770456517009408
# Failed retrieving tweet with id  771500966810099713
# Failed retrieving tweet with id  771380798096281600
# Failed retrieving tweet with id  771171053431250945
# Failed retrieving tweet with id  771136648247640064
# Failed retrieving tweet with id  771102124360998913
# Failed retrieving tweet with id  771014301343748096
# Failed retrieving tweet with id  771004394259247104
# Failed retrieving tweet with id  770787852854652928
# Failed retrieving tweet with id  770772759874076672
# Failed retrieving tweet with id  770743923962707968
# Failed retrieving tweet with id  770655142660169732
# Failed retrieving tweet with id  770414278348247044
# Failed retrieving tweet with id  770293558247038976
# Failed retrieving tweet with id  770093767776997377
# Failed retrieving tweet with id  770069151037685760
# Failed retrieving tweet with id  769940425801170949
# Failed retrieving tweet with id  769695466921623552
# Failed retrieving tweet with id  769335591808995329
# Failed retrieving tweet with id  769212283578875904
# Failed retrieving tweet with id  768970937022709760
# Failed retrieving tweet with id  768909767477751808
# Failed retrieving tweet with id  768855141948723200
# Failed retrieving tweet with id  768609597686943744
# Failed retrieving tweet with id  768596291618299904
# Failed retrieving tweet with id  768554158521745409
# Failed retrieving tweet with id  768473857036525572
# Failed retrieving tweet with id  768193404517830656
# Failed retrieving tweet with id  767884188863397888
# Failed retrieving tweet with id  767754930266464257
# Failed retrieving tweet with id  767500508068192258
# Failed retrieving tweet with id  767191397493538821
# Failed retrieving tweet with id  767122157629476866
# Failed retrieving tweet with id  766864461642756096
# Failed retrieving tweet with id  766793450729734144
# Failed retrieving tweet with id  766714921925144576
# Failed retrieving tweet with id  766693177336135680
# Failed retrieving tweet with id  766423258543644672
# Failed retrieving tweet with id  766313316352462849
# Failed retrieving tweet with id  766078092750233600
# Failed retrieving tweet with id  766069199026450432
# Failed retrieving tweet with id  766008592277377025
# Failed retrieving tweet with id  765719909049503744
# Failed retrieving tweet with id  765669560888528897
# Failed retrieving tweet with id  765395769549590528
# Failed retrieving tweet with id  765371061932261376
# Failed retrieving tweet with id  765222098633691136
# Failed retrieving tweet with id  764857477905154048
# Failed retrieving tweet with id  764259802650378240
# Failed retrieving tweet with id  763956972077010945
# Failed retrieving tweet with id  763837565564780549
# Failed retrieving tweet with id  763183847194451968
# Failed retrieving tweet with id  763167063695355904
# Failed retrieving tweet with id  763103485927849985
# Failed retrieving tweet with id  762699858130116608
# Failed retrieving tweet with id  762471784394268675
# Failed retrieving tweet with id  762464539388485633
# Failed retrieving tweet with id  762316489655476224
# Failed retrieving tweet with id  762035686371364864
# Failed retrieving tweet with id  761976711479193600
# Failed retrieving tweet with id  761750502866649088
# Failed retrieving tweet with id  761745352076779520
# Failed retrieving tweet with id  761672994376806400
# Failed retrieving tweet with id  761599872357261312
# Failed retrieving tweet with id  761371037149827077
# Failed retrieving tweet with id  761334018830917632
# Failed retrieving tweet with id  761292947749015552
# Failed retrieving tweet with id  761227390836215808
# Failed retrieving tweet with id  761004547850530816
# Failed retrieving tweet with id  760893934457552897
# Failed retrieving tweet with id  760656994973933572
# Failed retrieving tweet with id  760641137271070720
# Failed retrieving tweet with id  760539183865880579
# Failed retrieving tweet with id  760521673607086080
# Failed retrieving tweet with id  760290219849637889
# Failed retrieving tweet with id  760252756032651264
# Failed retrieving tweet with id  760190180481531904
# Failed retrieving tweet with id  760153949710192640
# Failed retrieving tweet with id  759943073749200896
# Failed retrieving tweet with id  759923798737051648
# Failed retrieving tweet with id  759846353224826880
# Failed retrieving tweet with id  759793422261743616
# Failed retrieving tweet with id  759566828574212096
# Failed retrieving tweet with id  759557299618865152
# Failed retrieving tweet with id  759447681597108224
# Failed retrieving tweet with id  759446261539934208
# Failed retrieving tweet with id  759197388317847553
# Failed retrieving tweet with id  759159934323924993
# Failed retrieving tweet with id  759099523532779520
# Failed retrieving tweet with id  759047813560868866
# Failed retrieving tweet with id  758854675097526272
# Failed retrieving tweet with id  758828659922702336
# Failed retrieving tweet with id  758740312047005698
# Failed retrieving tweet with id  758474966123810816
# Failed retrieving tweet with id  758467244762497024
# Failed retrieving tweet with id  758405701903519748
# Failed retrieving tweet with id  758355060040593408
# Failed retrieving tweet with id  758099635764359168
# Failed retrieving tweet with id  758041019896193024
# Failed retrieving tweet with id  757741869644341248
# Failed retrieving tweet with id  757729163776290825
# Failed retrieving tweet with id  757725642876129280
# Failed retrieving tweet with id  757611664640446465
# Failed retrieving tweet with id  757597904299253760
# Failed retrieving tweet with id  757596066325864448
# Failed retrieving tweet with id  757400162377592832
# Failed retrieving tweet with id  757393109802180609
# Failed retrieving tweet with id  757354760399941633
# Failed retrieving tweet with id  756998049151549440
# Failed retrieving tweet with id  756939218950160384
# Failed retrieving tweet with id  756651752796094464
# Failed retrieving tweet with id  756526248105566208
# Failed retrieving tweet with id  756303284449767430
# Failed retrieving tweet with id  756288534030475264
# Failed retrieving tweet with id  756275833623502848
# ...
# Failed retrieving tweet with id  671504605491109889
# Failed retrieving tweet with id  671497587707535361
# Failed retrieving tweet with id  671488513339211776
# Failed retrieving tweet with id  671486386088865792
# Failed retrieving tweet with id  671485057807351808
# Failed retrieving tweet with id  671390180817915904
# Failed retrieving tweet with id  671362598324076544
# Failed retrieving tweet with id  671357843010908160
# Failed retrieving tweet with id  671355857343524864
# Failed retrieving tweet with id  671347597085433856
# Failed retrieving tweet with id  671186162933985280
# Failed retrieving tweet with id  671182547775299584
# Failed retrieving tweet with id  671166507850801152
# Failed retrieving tweet with id  671163268581498880
# Failed retrieving tweet with id  671159727754231808
# Failed retrieving tweet with id  671154572044468225
# Failed retrieving tweet with id  671151324042559489
# Failed retrieving tweet with id  671147085991960577
# Failed retrieving tweet with id  671141549288370177
# Failed retrieving tweet with id  671138694582165504
# Failed retrieving tweet with id  671134062904504320
# Failed retrieving tweet with id  671122204919246848
# Failed retrieving tweet with id  671115716440031232
# Failed retrieving tweet with id  671109016219725825
# Failed retrieving tweet with id  670995969505435648
# Failed retrieving tweet with id  670842764863651840
# Failed retrieving tweet with id  670840546554966016
# Failed retrieving tweet with id  670838202509447168
# Failed retrieving tweet with id  670833812859932673
# Failed retrieving tweet with id  670832455012716544
# Failed retrieving tweet with id  670826280409919488
# Failed retrieving tweet with id  670823764196741120
# Failed retrieving tweet with id  670822709593571328
# Failed retrieving tweet with id  670815497391357952
# Failed retrieving tweet with id  670811965569282048
# Failed retrieving tweet with id  670807719151067136
# Failed retrieving tweet with id  670804601705242624
# Failed retrieving tweet with id  670803562457407488
# Failed retrieving tweet with id  670797304698376195
# Failed retrieving tweet with id  670792680469889025
# Failed retrieving tweet with id  670789397210615808
# Failed retrieving tweet with id  670786190031921152
# Failed retrieving tweet with id  670783437142401025
# Failed retrieving tweet with id  670782429121134593
# Failed retrieving tweet with id  670780561024270336
# Failed retrieving tweet with id  670778058496974848
# Failed retrieving tweet with id  670764103623966721
# Failed retrieving tweet with id  670755717859713024
# Failed retrieving tweet with id  670733412878163972
# Failed retrieving tweet with id  670727704916926465
# Failed retrieving tweet with id  670717338665226240
# Failed retrieving tweet with id  670704688707301377
# Failed retrieving tweet with id  670691627984359425
# Failed retrieving tweet with id  670679630144274432
# Failed retrieving tweet with id  670676092097810432
# Failed retrieving tweet with id  670668383499735048
# Failed retrieving tweet with id  670474236058800128
# Failed retrieving tweet with id  670468609693655041
# Failed retrieving tweet with id  670465786746662913
# Failed retrieving tweet with id  670452855871037440
# Failed retrieving tweet with id  670449342516494336
# Failed retrieving tweet with id  670444955656130560
# Failed retrieving tweet with id  670442337873600512
# Failed retrieving tweet with id  670435821946826752
# Failed retrieving tweet with id  670434127938719744
# Failed retrieving tweet with id  670433248821026816
# Failed retrieving tweet with id  670428280563085312
# Failed retrieving tweet with id  670427002554466305
# Failed retrieving tweet with id  670421925039075328
# Failed retrieving tweet with id  670420569653809152
# Failed retrieving tweet with id  670417414769758208
# Failed retrieving tweet with id  670411370698022913
# Failed retrieving tweet with id  670408998013820928
# Failed retrieving tweet with id  670403879788544000
# Failed retrieving tweet with id  670385711116361728
# Failed retrieving tweet with id  670374371102445568
# Failed retrieving tweet with id  670361874861563904
# Failed retrieving tweet with id  670338931251150849
# Failed retrieving tweet with id  670319130621435904
# Failed retrieving tweet with id  670303360680108032
# Failed retrieving tweet with id  670290420111441920
# Failed retrieving tweet with id  670093938074779648
# Failed retrieving tweet with id  670086499208155136
# Failed retrieving tweet with id  670079681849372674
# Failed retrieving tweet with id  670073503555706880
# Failed retrieving tweet with id  670069087419133954
# Failed retrieving tweet with id  670061506722140161
# Failed retrieving tweet with id  670055038660800512
# Failed retrieving tweet with id  670046952931721218
# Failed retrieving tweet with id  670040295598354432
# Failed retrieving tweet with id  670037189829525505
# Failed retrieving tweet with id  670003130994700288
# Failed retrieving tweet with id  669993076832759809
# Failed retrieving tweet with id  669972011175813120
# Failed retrieving tweet with id  669970042633789440
# Failed retrieving tweet with id  669942763794931712
# Failed retrieving tweet with id  669926384437997569
# Failed retrieving tweet with id  669923323644657664
# Failed retrieving tweet with id  669753178989142016
# Failed retrieving tweet with id  669749430875258880
# Failed retrieving tweet with id  669684865554620416
# Failed retrieving tweet with id  669683899023405056
# Failed retrieving tweet with id  669682095984410625
# Failed retrieving tweet with id  669680153564442624
# Failed retrieving tweet with id  669661792646373376
# Failed retrieving tweet with id  669625907762618368
# Failed retrieving tweet with id  669603084620980224
# Failed retrieving tweet with id  669597912108789760
# Failed retrieving tweet with id  669583744538451968
# Failed retrieving tweet with id  669573570759163904
# Failed retrieving tweet with id  669571471778410496
# Failed retrieving tweet with id  669567591774625800
# Failed retrieving tweet with id  669564461267722241
# Failed retrieving tweet with id  669393256313184256
# Failed retrieving tweet with id  669375718304980992
# Failed retrieving tweet with id  669371483794317312
# Failed retrieving tweet with id  669367896104181761
# Failed retrieving tweet with id  669363888236994561
# Failed retrieving tweet with id  669359674819481600
# Failed retrieving tweet with id  669354382627049472
# Failed retrieving tweet with id  669353438988365824
# Failed retrieving tweet with id  669351434509529089
# Failed retrieving tweet with id  669328503091937280
# Failed retrieving tweet with id  669327207240699904
# Failed retrieving tweet with id  669324657376567296
# Failed retrieving tweet with id  669216679721873412
# Failed retrieving tweet with id  669214165781868544
# Failed retrieving tweet with id  669203728096960512
# Failed retrieving tweet with id  669037058363662336
# Failed retrieving tweet with id  669015743032369152
# Failed retrieving tweet with id  669006782128353280
# Failed retrieving tweet with id  669000397445533696
# Failed retrieving tweet with id  668994913074286592
# Failed retrieving tweet with id  668992363537309700
# Failed retrieving tweet with id  668989615043424256
# Failed retrieving tweet with id  668988183816871936
# Failed retrieving tweet with id  668986018524233728
# Failed retrieving tweet with id  668981893510119424
# Failed retrieving tweet with id  668979806671884288
# Failed retrieving tweet with id  668975677807423489
# Failed retrieving tweet with id  668967877119254528
# Failed retrieving tweet with id  668960084974809088
# Failed retrieving tweet with id  668955713004314625
# Failed retrieving tweet with id  668932921458302977
# Failed retrieving tweet with id  668902994700836864
# Failed retrieving tweet with id  668892474547511297
# Failed retrieving tweet with id  668872652652679168
# Failed retrieving tweet with id  668852170888998912
# Failed retrieving tweet with id  668826086256599040
# Failed retrieving tweet with id  668815180734689280
# Failed retrieving tweet with id  668779399630725120
# Failed retrieving tweet with id  668655139528511488
# Failed retrieving tweet with id  668645506898350081
# Failed retrieving tweet with id  668643542311546881
# Failed retrieving tweet with id  668641109086707712
# Failed retrieving tweet with id  668636665813057536
# Failed retrieving tweet with id  668633411083464705
# Failed retrieving tweet with id  668631377374486528
# Failed retrieving tweet with id  668627278264475648
# Failed retrieving tweet with id  668625577880875008
# Failed retrieving tweet with id  668623201287675904
# Failed retrieving tweet with id  668620235289837568
# Failed retrieving tweet with id  668614819948453888
# Failed retrieving tweet with id  668587383441514497
# Failed retrieving tweet with id  668567822092664832
# Failed retrieving tweet with id  668544745690562560
# Failed retrieving tweet with id  668542336805281792
# Failed retrieving tweet with id  668537837512433665
# Failed retrieving tweet with id  668528771708952576
# Failed retrieving tweet with id  668507509523615744
# Failed retrieving tweet with id  668496999348633600
# Failed retrieving tweet with id  668484198282485761
# Failed retrieving tweet with id  668480044826800133
# Failed retrieving tweet with id  668466899341221888
# Failed retrieving tweet with id  668297328638447616
# Failed retrieving tweet with id  668291999406125056
# Failed retrieving tweet with id  668286279830867968
# Failed retrieving tweet with id  668274247790391296
# Failed retrieving tweet with id  668268907921326080
# Failed retrieving tweet with id  668256321989451776
# Failed retrieving tweet with id  668248472370458624
# Failed retrieving tweet with id  668237644992782336
# Failed retrieving tweet with id  668226093875376128
# Failed retrieving tweet with id  668221241640230912
# Failed retrieving tweet with id  668204964695683073
# Failed retrieving tweet with id  668190681446379520
# Failed retrieving tweet with id  668171859951755264
# Failed retrieving tweet with id  668154635664932864
# Failed retrieving tweet with id  668142349051129856
# Failed retrieving tweet with id  668113020489474048
# Failed retrieving tweet with id  667937095915278337
# Failed retrieving tweet with id  667924896115245057
# Failed retrieving tweet with id  667915453470232577
# Failed retrieving tweet with id  667911425562669056
# Failed retrieving tweet with id  667902449697558528
# Failed retrieving tweet with id  667886921285246976
# Failed retrieving tweet with id  667885044254572545
# Failed retrieving tweet with id  667878741721415682
# Failed retrieving tweet with id  667873844930215936
# Failed retrieving tweet with id  667866724293877760
# Failed retrieving tweet with id  667861340749471744
# Failed retrieving tweet with id  667832474953625600
# Failed retrieving tweet with id  667806454573760512
# Failed retrieving tweet with id  667801013445750784
# Failed retrieving tweet with id  667793409583771648
# Failed retrieving tweet with id  667782464991965184
# Failed retrieving tweet with id  667773195014021121
# Failed retrieving tweet with id  667766675769573376
# Failed retrieving tweet with id  667728196545200128
# Failed retrieving tweet with id  667724302356258817
# Failed retrieving tweet with id  667550904950915073
# Failed retrieving tweet with id  667550882905632768
# Failed retrieving tweet with id  667549055577362432
# Failed retrieving tweet with id  667546741521195010
# Failed retrieving tweet with id  667544320556335104
# Failed retrieving tweet with id  667538891197542400
# Failed retrieving tweet with id  667534815156183040
# Failed retrieving tweet with id  667530908589760512
# Failed retrieving tweet with id  667524857454854144
# Failed retrieving tweet with id  667517642048163840
# Failed retrieving tweet with id  667509364010450944
# Failed retrieving tweet with id  667502640335572993
# Failed retrieving tweet with id  667495797102141441
# Failed retrieving tweet with id  667491009379606528
# Failed retrieving tweet with id  667470559035432960
# Failed retrieving tweet with id  667455448082227200
# Failed retrieving tweet with id  667453023279554560
# Failed retrieving tweet with id  667443425659232256
# Failed retrieving tweet with id  667437278097252352
# Failed retrieving tweet with id  667435689202614272
# Failed retrieving tweet with id  667405339315146752
# Failed retrieving tweet with id  667393430834667520
# Failed retrieving tweet with id  667369227918143488
# Failed retrieving tweet with id  667211855547486208
# Failed retrieving tweet with id  667200525029539841
# Failed retrieving tweet with id  667192066997374976
# Failed retrieving tweet with id  667188689915760640
# Failed retrieving tweet with id  667182792070062081
# Failed retrieving tweet with id  667177989038297088
# Failed retrieving tweet with id  667176164155375616
# Failed retrieving tweet with id  667174963120574464
# Failed retrieving tweet with id  667171260800061440
# Failed retrieving tweet with id  667165590075940865
# Failed retrieving tweet with id  667160273090932737
# Failed retrieving tweet with id  667152164079423490
# Failed retrieving tweet with id  667138269671505920
# Failed retrieving tweet with id  667119796878725120
# Failed retrieving tweet with id  667090893657276420
# Failed retrieving tweet with id  667073648344346624
# Failed retrieving tweet with id  667070482143944705
# Failed retrieving tweet with id  667065535570550784
# Failed retrieving tweet with id  667062181243039745
# Failed retrieving tweet with id  667044094246576128
# Failed retrieving tweet with id  667012601033924608
# Failed retrieving tweet with id  666996132027977728
# Failed retrieving tweet with id  666983947667116034
# Failed retrieving tweet with id  666837028449972224
# Failed retrieving tweet with id  666835007768551424
# Failed retrieving tweet with id  666826780179869698
# Failed retrieving tweet with id  666817836334096384
# Failed retrieving tweet with id  666804364988780544
# Failed retrieving tweet with id  666786068205871104
# Failed retrieving tweet with id  666781792255496192
# Failed retrieving tweet with id  666776908487630848
# Failed retrieving tweet with id  666739327293083650
# Failed retrieving tweet with id  666701168228331520
# Failed retrieving tweet with id  666691418707132416
# Failed retrieving tweet with id  666649482315059201
# Failed retrieving tweet with id  666644823164719104
# Failed retrieving tweet with id  666454714377183233
# Failed retrieving tweet with id  666447344410484738
# Failed retrieving tweet with id  666437273139982337
# Failed retrieving tweet with id  666435652385423360
# Failed retrieving tweet with id  666430724426358785
# Failed retrieving tweet with id  666428276349472768
# Failed retrieving tweet with id  666421158376562688
# Failed retrieving tweet with id  666418789513326592
# Failed retrieving tweet with id  666411507551481857
# Failed retrieving tweet with id  666407126856765440
# Failed retrieving tweet with id  666396247373291520
# Failed retrieving tweet with id  666373753744588802
# Failed retrieving tweet with id  666362758909284353
# Failed retrieving tweet with id  666353288456101888
# Failed retrieving tweet with id  666345417576210432
# Failed retrieving tweet with id  666337882303524864
# Failed retrieving tweet with id  666293911632134144
# Failed retrieving tweet with id  666287406224695296
# Failed retrieving tweet with id  666273097616637952
# Failed retrieving tweet with id  666268910803644416
# Failed retrieving tweet with id  666104133288665088
# Failed retrieving tweet with id  666102155909144576
# Failed retrieving tweet with id  666099513787052032
# Failed retrieving tweet with id  666094000022159362
# Failed retrieving tweet with id  666082916733198337
# Failed retrieving tweet with id  666073100786774016
# Failed retrieving tweet with id  666071193221509120
# Failed retrieving tweet with id  666063827256086533
# Failed retrieving tweet with id  666058600524156928
# Failed retrieving tweet with id  666057090499244032
# Failed retrieving tweet with id  666055525042405380
# Failed retrieving tweet with id  666051853826850816
# Failed retrieving tweet with id  666050758794694657
# Failed retrieving tweet with id  666049248165822465
# Failed retrieving tweet with id  666044226329800704
# Failed retrieving tweet with id  666033412701032449
# Failed retrieving tweet with id  666029285002620928
# Failed retrieving tweet with id  666020888022790149

# %%
# Read the contents of the created file and create a dataframe with the fields of interest 
# Reading gathered files
###more_data = pd.read_json('tweet_json.txt', lines = True,encoding='utf-8')

df = []
with open('tweet_json.txt') as f:
    for line in f:
        tweet = (json.loads(line))
        tweet_id = tweet['id']
        retweet_count = tweet['retweet_count']
        favorite_count = tweet['favorite_count']
        create_date = tweet['created_at']
        df.append({'retweet_count' : retweet_count,
                  'favorite_count' : favorite_count,
                  'create_date' : create_date,
                  'tweet_id' : tweet_id})
        
more_data = pd.DataFrame(df, columns = ['tweet_id', 'retweet_count', 'favorite_count', 'create_date'])

# %% [markdown]
# # Assess

# %% [markdown]
# Assessing is the process of checking the data sets for two things: quality issues and lack of tidiness. Data that has quality issues has problems with its contents: missing, corrupted, inacurate, duplicate or incorrect data. This is called "dirty data". In the contrary, "untidy" or "messy" data has specific structural issues.
#
# You look for these issues in two ways: visually and programatically. When you detect an issue you document it, to make cleaning easier. You don't write yet how to clean the data, but only state the observation.
#
# Visual assessment is great for getting acquainted with the data and understanding what it is all about. That's what we will do now:

# %%
# assessing the file with the retrieved data for WeRateDogs tweets
feed.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %%
# assessing the file with the breed predictions for each dog
predictions.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
more_data.head()
# Out:
#              tweet_id  retweet_count  favorite_count  \
# 0  892420643555336193           8323           38047
# 1  892177421306343426           6149           32665
# 2  891815181378084864           4069           24579
# 3  891689557279858688           8469           41402
# 4  891327558926688256           9164           39579
#
#                       create_date
# 0  Tue Aug 01 16:23:56 +0000 2017
# 1  Tue Aug 01 00:17:27 +0000 2017
# 2  Mon Jul 31 00:18:03 +0000 2017
# 3  Sun Jul 30 15:58:51 +0000 2017
# 4  Sat Jul 29 16:00:24 +0000 2017

# %% [markdown]
# ### Programatical Assessment
# After assessing visually the three datasets and identifying several tidiness issues, we now go deeper using Programatic Assessment:

# %%
feed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %% [markdown]
# The missing data for retweets and replies is fine, since we are not interested in those. 59 expanded URLs are missing.

# %%
predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   object
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %%
more_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2340 entries, 0 to 2339
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2340 non-null   int64
#  1   retweet_count   2340 non-null   int64
#  2   favorite_count  2340 non-null   int64
#  3   create_date     2340 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 73.2+ KB

# %%
# We test whether the missing expanded URLs are a problem.
# If there is a link in the tweet's text and no expanded URL then there is an issue

explore = feed[feed['expanded_urls'].isnull()]
explore['text'].str.contains('http').sum()
# Out:
# 0

# %% [markdown]
# No issue there. Every tweet with an url has an expanded URL. Those without one are usually retweets or replies.

# %%
# value counts for the source column
feed.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
# every numerator not other than 10-14 in the dogs rating is a possible quality issue
feed.rating_numerator.value_counts().sort_index(ascending=False)
# Out:
# 1776      1
# 960       1
# 666       1
# 420       2
# 204       1
# 182       1
# 165       1
# 144       1
# 143       1
# 121       1
# 99        1
# 88        1
# 84        1
# 80        1
# 75        2
# 60        1
# 50        1
# 45        1
# 44        1
# 27        1
# 26        1
# 24        1
# 20        1
# 17        1
# 15        2
# 14       54
# 13      351
# 12      558
# 11      464
# 10      461
# 9       158
# 8       102
# 7        55
# 6        32
# 5        37
# 4        17
# 3        19
# 2         9
# 1         9
# 0         2
# Name: rating_numerator, dtype: int64

# %%
# every denominator not equal to 10 in the dogs rating is a possible quality issue
feed.rating_denominator.value_counts().sort_index(ascending=False)
# Out:
# 170       1
# 150       1
# 130       1
# 120       1
# 110       1
# 90        1
# 80        2
# 70        1
# 50        3
# 40        1
# 20        2
# 16        1
# 15        1
# 11        3
# 10     2333
# 7         1
# 2         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
# we check for duplicated IDs in the feeds dataframe
feed[feed.tweet_id.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# There are no duplicated tweets in the dataset, testing by its ID

# %%
predictions.describe()
# Out:
#            img_num      p1_conf       p2_conf       p3_conf
# count  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean      1.203855     0.594548  1.345886e-01  6.032417e-02
# std       0.561875     0.271174  1.006657e-01  5.090593e-02
# min       1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%       1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%       1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%       1.000000     0.843855  1.955655e-01  9.180755e-02
# max       4.000000     1.000000  4.880140e-01  2.734190e-01

# %% [markdown]
# The predictions dataframe is the only one with numerical data. With .describe() we can check whether the ranges, means and quartiles make sense. In this test, we correctly see that the probability for the first guess has the largest value. We also see that the highest probability is equal to 1, which is expected.

# %%
# Checking for duplicated columns by creating a list of every column in every dataset
all_columns = pd.Series(list(feed) + list(predictions) + list(more_data))
# all_columns
all_columns[all_columns.duplicated()]
# Out:
# 17    tweet_id
# 29    tweet_id
# dtype: object

# %% [markdown]
# The only duplicated column is tweet_id, which is ok. This is how tidiness is assessed programatically.

# %% [markdown]
# ## Issues

# %% [markdown]
# Quality
#
# `twitter-archive-enhanced.csv`
#
# - The extracted rating numerators are wrong when they are decimals like 13.5. Status:solved.
# - source column has innecesary HTML code. Status: solved
# - some tweets are retweets or replies. Status: solved
# - timestamp column is not in datatime format. Status: solved
# - The rating for dog in tweet with id 716439118184652801, 722974582966214656 and 682962037429899265 are wrong. Status: solved
# - Many dog names are wrong, including hose with id 740373189193256964 and 770414278348247044. Many names are just other words in English. Status: solved
# - The dog stage for dog in tweet with id 854010172552949760 is wrong. Status: solved
# - some rows have several identical values in the expanded_url column concatenated by a comma. Status: solved
# - Tweet_id fields in the three datasets are stored as numeric values and should be strings. Status: solved
# - Predictions are spread in three columns. Status: solved
# - Confidence intervals are spread in three columns. Status: solved
# - Dog tests are spread in three columns. Status: solved
# `additional twitter data`

# %% [markdown]
# `more_data` dataframe
#
# - Retweet and favorite count columns have float as datatype and should be int. Status: solved
#
#
# ### Tidiness
#
# `twitter-archive-enhanced.csv`
#
# - Dog "stage" is spread in four columns. Status: solved
# - Data about dogs and tweets in a same dataset. Status: solved
# - The dog's raiting appears both in the "text" column and the rating numerator/denominator columns. Status: will not be solved here
# - The link to the dog's photo is part of the status text and should have own column. Status: will not be solved here
# `image-predictions.tsv`
#
#
#
# - Create date exists already in twitter-archive-enhanced.tsv. Status: solved
# - The dataset is split from the main dataset describing tweets. Status: solved
#
# ## Clean
# Cleaning the data is the third and last step in the data wrangling process. The issues that were identified are solved programatically, in three steps: Define, Code and Test. We begin by creating copies of each of our three datasets

# %%
# create copies of the datasets
feed_clean = feed.copy()
predictions_clean = predictions.copy()
more_data_clean = more_data.copy()

# %% [markdown]
# ### Some tweets are retweets or replies

# %% [markdown]
# ## Define

# %% [markdown]
# Remove all observations in the feed_clean dataset that have values in the rows in_reply_to_status_id or retweeted_status_id. Then remove those two columns plus retweeted_status_user_id, retweeted_status_timestamp and in_reply_to_user_id

# %% [markdown]
# ## Code

# %%
feed_clean = feed_clean[(feed_clean['in_reply_to_status_id'].isna() == True)  & (feed_clean['retweeted_status_id'].isna() == True)]

feed_clean = feed_clean.drop(['in_reply_to_status_id',
                              'in_reply_to_user_id',
                              'retweeted_status_id',
                              'retweeted_status_user_id',
                              'retweeted_status_timestamp'],
                            axis = 1)

# %% [markdown]
# ## Test

# %%
feed_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   object
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   doggo               2097 non-null   object
#  9   floofer             2097 non-null   object
#  10  pupper              2097 non-null   object
#  11  puppo               2097 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 213.0+ KB

# %% [markdown]
# The extracted rating numerators are wrong when they are decimals like 13.5.

# %% [markdown]
# ## Define
#
#
# Change datatype and use regex to extract the ratings numerators again.

# %% [markdown]
# ## Code

# %%
feed_clean['rating_numerator'] = feed_clean['rating_numerator'].astype('float')

# %%
feed_clean['rating_numerator'] = feed_clean['text'].str.extract('(\d+\.*\d*\/\d+)', expand=False).str.split('/').str[0]

# %% [markdown]
# ## Test

# %%
print(feed_clean.rating_numerator.dtype)
# Out:
# object

# %%
feed_clean.loc[feed_clean['tweet_id'] == 883482846933004288, 'rating_numerator']
# Out:
# 45    13.5
# Name: rating_numerator, dtype: object

# %% [markdown]
# ### Data about dogs and tweets in a same dataset

# %% [markdown]
# ## Define
# In order to have observational units in their own table, we need to split the feed_clean data-set into a tweets table and a dogs table. This is a design decision because there are many several tweets that include information and ratings for more than one dog. Ratings and dog stages refer to dogs, whereas retweets an likes are related to the tweets.
#
# ## Code

# %%
dogs = feed_clean[['tweet_id', 'name', 'doggo', 'floofer', 'pupper', 'puppo', 'rating_numerator', 'rating_denominator']].copy()
tweets = feed_clean.drop(['name', 'doggo', 'floofer', 'pupper', 'puppo', 'rating_numerator', 'rating_denominator'], axis=1)

# %% [markdown]
# ## Test

# %%
print(tweets.columns)
print(dogs.columns)
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'expanded_urls'], dtype='object')
# Index(['tweet_id', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'rating_numerator', 'rating_denominator'],
#       dtype='object')

# %% [markdown]
# ### Dog "stage" is spread in four columns
#
# ## Define
# We have values as variables in the now called dogs table. We will melt the columns doggo, floofer, pupper, puppo into a new variable called dog_stage. Before melting, create a new column to identify those dogs with dog stage 'unknown'
#
# ## Code

# %%
# we want to create first an extra column to tag those dogs without a recognized stage. 
# This will help cleaning the dataset afterwards
def u(row):
    if row ['doggo'] == 'None' and row ['floofer'] == 'None' and row ['pupper'] == 'None' and row ['puppo'] == 'None':
        val = 'unknown'
    else:
        val ='None'
    return val

dogs['unknown'] = dogs.apply(u, axis=1)

# %%
dogs.sample()
# Out:
#                tweet_id  name doggo floofer pupper puppo rating_numerator  \
# 523  809448704142938112  None  None    None   None  None               12
#
#      rating_denominator  unknown
# 523                  10  unknown

# %%
# we melt the different dog stages into a new column calle 'dog_stage'
dogs = pd.melt(dogs, id_vars =['tweet_id', 'name', 'rating_numerator','rating_denominator'],
                     value_vars = ['doggo', 'floofer', 'pupper', 'puppo', 'unknown'],
                     var_name = 'dog_stage', 
                    value_name = 'value')

# %%
# clean the duplicated rows created in the preious process and drop the 'value' variable
dogs = dogs[dogs['value']!= 'None']
dogs = dogs.drop('value', axis=1)

# %% [markdown]
# ## Test

# %%
dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2108 entries, 9 to 10484
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2108 non-null   int64
#  1   name                2108 non-null   object
#  2   rating_numerator    2108 non-null   object
#  3   rating_denominator  2108 non-null   int64
#  4   dog_stage           2108 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 98.8+ KB

# %% [markdown]
# It is normal that now we have more records (2,108 vs 2,097), because some tweets referred to more than one dog and included more than one dog stage
#
# ### Predictions are spread in three columns
#
# ## Define
# The different predictions, the confidence and the test whether the prediction is a dog or not need to be melted into four columns: prediction_number, prediction, confidence and dog
#
# ## Code

# %%
# This script iterates the melting process for the three categories of data: prediction, confidence and dog test. 
# at the end we have a clean tidy dataset.

# create 'prediction_number' and 'prediction' columns
predictions_clean = pd.melt(predictions_clean, id_vars = ['tweet_id', 'jpg_url', 'img_num', 'p1_conf', 'p1_dog',
       'p2_conf', 'p2_dog', 'p3_conf', 'p3_dog'],
               var_name = 'prediction_number',
               value_name = 'prediction')

# create 'confidence' column
predictions_clean = pd.melt(predictions_clean, id_vars = ['tweet_id', 'jpg_url', 'img_num', 'p1_dog',
       'p2_dog', 'p3_dog', 'prediction_number', 'prediction'],
               var_name = 'to_delete',
               value_name = 'confidence')

# remove newly created duplicated rows
predictions_clean = predictions_clean[predictions_clean['prediction_number'] == predictions_clean['to_delete'].str[:2]]
# remove unnecesary column
predictions_clean = predictions_clean.drop('to_delete', axis=1)

# create 'dog' column
predictions_clean = pd.melt(predictions_clean, id_vars = ['tweet_id', 'jpg_url', 'img_num','prediction_number', 'prediction', 'confidence'],
               var_name = 'to_delete2',
               value_name = 'dog')

# remove newly created duplicated rows
predictions_clean = predictions_clean[predictions_clean['prediction_number'] == predictions_clean['to_delete2'].str[:2]]

# remove unnecesary column
predictions_clean = predictions_clean.drop('to_delete2', axis=1)
# remove 'p' from prediction number
predictions_clean['prediction_number'] = predictions_clean['prediction_number'].str[1]

# %% [markdown]
# ## Test

# %%
predictions_clean.sort_values(by = ['tweet_id', 'prediction_number']).head(9)
# Out:
#                  tweet_id                                          jpg_url  \
# 0      666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 8300   666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 16600  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1      666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 8301   666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 16601  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2      666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 8302   666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 16602  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
#
#        img_num prediction_number              prediction  confidence   dog
# 0            1                 1  Welsh_springer_spaniel    0.465074  True
# 8300         1                 2                  collie    0.156665  True
# 16600        1                 3       Shetland_sheepdog    0.061428  True
# 1            1                 1                 redbone    0.506826  True
# 8301         1                 2      miniature_pinscher    0.074192  True
# 16601        1                 3     Rhodesian_ridgeback    0.072010  True
# 2            1                 1         German_shepherd    0.596461  True
# 8302         1                 2                malinois    0.138584  True
# 16602        1                 3              bloodhound    0.116197  True

# %% [markdown]
# ### Create date not needed in more_data_clean (field already exists in tweets dataframe)
#
# ## Define
# Remove create_date from more_data_clean dataframe
#
# ## Code

# %%
more_data_clean = more_data_clean.drop('create_date', axis = 1)

# %% [markdown]
# ## Test

# %%
more_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2340 entries, 0 to 2339
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2340 non-null   int64
#  1   retweet_count   2340 non-null   int64
#  2   favorite_count  2340 non-null   int64
# dtypes: int64(3)
# memory usage: 55.0 KB

# %% [markdown]
# ### The more_data dataset is split from the main dataset describing tweets
#
# ## Define
# Merge `more_data_clean` into `tweets`
#
# ## Code

# %%
# merge both dataframes on 'tweet_id'. Left join to preserve all tweets, independent of whether retweet info
# could be retrieved through twitter's API
tweets = tweets.merge(more_data_clean, how = 'left', on = 'tweet_id')

# %% [markdown]
# ## Test

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2096
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2097 non-null   int64
#  1   timestamp       2097 non-null   object
#  2   source          2097 non-null   object
#  3   text            2097 non-null   object
#  4   expanded_urls   2094 non-null   object
#  5   retweet_count   2095 non-null   float64
#  6   favorite_count  2095 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 131.1+ KB

# %% [markdown]
# ### source column has innecesary HTML code
#
# ## Define
# Remove the HTML from the source column in the feed dataframe, leaving only the clear name of the source. Use Beautiful Soup because the text is the contents of an HTML tag.
#
# ## Code

# %%
# Iterate through each row and extract the source's text with beautiful soup

from bs4 import BeautifulSoup as bs

new_source = []
for line, row in tweets.iterrows():
    soup = bs(row.source)
    x = soup.find('a').contents[0]
    new_source.append(x)
    
tweets['source'] = new_source

# %% [markdown]
# ## Test

# %%
pd.Series(new_source).value_counts()
# Out:
# Twitter for iPhone     1964
# Vine - Make a Scene      91
# Twitter Web Client       31
# TweetDeck                11
# dtype: int64

# %% [markdown]
# ### timestamp column is not in datatime format
#
# ## Define
# Change timestamp datatype in tweets dataframe from object to datatime type
#
# ## Code

# %%
tweets['timestamp'] = pd.to_datetime(tweets['timestamp'])

# %% [markdown]
# ## Test

# %%
tweets.dtypes
# Out:
# tweet_id                        int64
# timestamp         datetime64[ns, UTC]
# source                         object
# text                           object
# expanded_urls                  object
# retweet_count                 float64
# favorite_count                float64
# dtype: object

# %% [markdown]
# - The rating for dog in tweet with id 716439118184652801 is wrong
# - The rating for dog in tweet with id 722974582966214656 is wrong
# - The rating for dogs in tweet with id 682962037429899265 is wrong

# %% [markdown]
# ## Define
# Look up for rating in tweet's text and update rating in dogs table
#
# ## Code

# %%
dogs.loc[dogs['tweet_id'] == 716439118184652801, 'rating_numerator'] = 11
dogs.loc[dogs['tweet_id'] == 716439118184652801, 'rating_denominator'] = 10

dogs.loc[dogs['tweet_id'] == 722974582966214656, 'rating_numerator'] = 13
dogs.loc[dogs['tweet_id'] == 722974582966214656, 'rating_denominator'] = 10

dogs.loc[dogs['tweet_id'] == 682962037429899265, 'rating_numerator'] = 10
dogs.loc[dogs['tweet_id'] == 682962037429899265, 'rating_denominator'] = 10

# %% [markdown]
# ## Test

# %%
ids = [716439118184652801, 722974582966214656, 682962037429899265]
dogs.loc[dogs['tweet_id'].isin(ids), ['tweet_id','rating_numerator', 'rating_denominator']]
# Out:
#                 tweet_id rating_numerator  rating_denominator
# 9336  722974582966214656               13                  10
# 9373  716439118184652801               11                  10
# 9814  682962037429899265               10                  10

# %% [markdown]
# ### Many dog names are wrong, including hose with id 740373189193256964 and 770414278348247044. Many names are just other words in English
#
# ## Define
# Look up and correct the dog's names in the dogs table
#
# ## Code

# %%
dogs.loc[dogs['tweet_id'] == 887517139158093824, 'name'] = 'None'
dogs.loc[dogs['tweet_id'] == 770414278348247044, 'name'] = 'Al Cabone'

# %% [markdown]
# ## Test

# %%
ids = [887517139158093824, 770414278348247044]
dogs.loc[dogs['tweet_id'].isin(ids), ['tweet_id','name']]
# Out:
#                 tweet_id       name
# 8409  887517139158093824       None
# 9020  770414278348247044  Al Cabone

# %% [markdown]
# ### The dog stage for dog in tweet with id 854010172552949760 is wrong
#
# ## Define
# Look up stage and correct stage in dogs table
#
# ## Code

# %%
dogs.loc[dogs['tweet_id'] == 854010172552949760, 'dog_stage'] = 'floofer'
dogs.drop(2258, inplace = True)

# %% [markdown]
# ## Test

# %%
dogs.loc[dogs['tweet_id'] == 854010172552949760 , ['tweet_id','dog_stage']]
# Out:
#                tweet_id dog_stage
# 161  854010172552949760   floofer

# %% [markdown]
# ## Define
#
# Split value to keep only the first URL in the column expanded_urls in the tweets dataset. Rename column to expanded_url
#
# ## Code

# %%
tweets['expanded_urls'] = tweets['expanded_urls'].str.split(',', expand=True)[0]

tweets = tweets.rename(index=str, columns={"expanded_urls": "expanded_url"})

# %% [markdown]
# ## Test

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2097 entries, 0 to 2096
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2097 non-null   int64
#  1   timestamp       2097 non-null   datetime64[ns, UTC]
#  2   source          2097 non-null   object
#  3   text            2097 non-null   object
#  4   expanded_url    2094 non-null   object
#  5   retweet_count   2095 non-null   float64
#  6   favorite_count  2095 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(2), int64(1), object(3)
# memory usage: 131.1+ KB

# %%
tweets['expanded_url'].str.contains(',').sum()
# Out:
# 0

# %% [markdown]
# ## Define
#
# Change the numeric datatypes for the tweet_id variable from int to object in the three datasets
#
# ## Code

# %%
tweets['tweet_id'] = tweets['tweet_id'].astype(str)
dogs['tweet_id'] = dogs['tweet_id'].astype(str)
predictions['tweet_id'] = predictions['tweet_id'].astype(str)

# %% [markdown]
# ## Test

# %%
print(tweets.tweet_id.dtype)
print(dogs.tweet_id.dtype)
print(predictions.tweet_id.dtype)
# Out:
# object
# object
# object

# %% [markdown]
# ### Retweet and favorite count are in float format.
#
# ## Define
# Change the datatypes for the retweet_count and favorite_count variables from float to int in tweets dataset
#
# ## Code

# %%
# I need to start by changing NaNs into 0, for the dtype conversion to int to work
tweets['retweet_count'] = tweets['retweet_count'].fillna(0).astype(int)
tweets['favorite_count'] = tweets['favorite_count'].fillna(0).astype(int)
tweets['retweet_count'] = tweets['retweet_count'].astype(int)
tweets['favorite_count'] = tweets['favorite_count'].astype(int)

# %% [markdown]
# ## Test

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2097 entries, 0 to 2096
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2097 non-null   object
#  1   timestamp       2097 non-null   datetime64[ns, UTC]
#  2   source          2097 non-null   object
#  3   text            2097 non-null   object
#  4   expanded_url    2094 non-null   object
#  5   retweet_count   2097 non-null   int64
#  6   favorite_count  2097 non-null   int64
# dtypes: datetime64[ns, UTC](1), int64(2), object(4)
# memory usage: 131.1+ KB

# %% [markdown]
# ### The values for the column "floffer" should not be capitalized to maintain integrity with the others
#
# ## Define
# Apply string methods to un-capitalize Floffer in the dog_stage values of the dogs dataset
#
# ## Code

# %%
dogs['dog_stage'] = dogs['dog_stage'].str.lower()

# %% [markdown]
# ## Test

# %%
dogs['dog_stage'].value_counts()
# Out:
# unknown    1761
# pupper      230
# doggo        82
# puppo        24
# floofer      10
# Name: dog_stage, dtype: int64

# %% [markdown]
# This concludes my cleaning of the identified issues for the project's datasets. As per the project's guidelines, the end result does not to solve every issue in the data (there are many more), but only 8 qulity issues and 2 tidiness issues. The goal is to demonstrate data wrangling skills and not to achieve a perfectly clean master dataset. After the completion with the cleaning phase, all that is left to be done is to save the cleaned master datasets, which in this case will be three tables with independent observational units (dogs.csv, tweets.csv and predictions.csv), and a master dataset (twitter_archive_master.csv) that joins the tweets data to the dogs data. Please note that the separator will be set to ';', which is the default for the locale in Germany.

# %%
# save the three tables with independent observational units
tweets.to_csv('tweets.csv', sep=';', index=False)
dogs.to_csv('dogs.csv', sep=';', index=False)
predictions.to_csv('predictions.csv', sep=';', index=False)

# %%
# create and save a master dataset. The key needs to be set to 'tweet_id' in order for the join to work.
twitter_archive_master = dogs.set_index('tweet_id').join(tweets.set_index('tweet_id'), on='tweet_id', how='left')
twitter_archive_master.to_csv('twitter_archive_master.csv', sep=';', index=False)

# %% [markdown]
# ## Analysis
# With a cleaned dataset we can now proceed to perform some basic analysis to obtain insights from the data. I will explore the data to try and solve the following questions:
#
# - Are retweets and replies correlated?
# - Which are the most common dog stage?
# - What dog stage receives more likes and retweets?
# - What dog stage receives the best ratings?
# - What's the distribution for the retweet count?

# %%
import altair as alt

# %%
tweets_master = pd.read_csv('twitter_archive_master.csv', sep=";")

# %%
chart = alt.Chart(tweets).mark_point()

# %%
alt.Chart(tweets_master[tweets_master['dog_stage']!= 'unknown']).mark_point(opacity = 0.5).encode(
    alt.X('retweet_count',scale=alt.Scale(type='log'), bin=True),
    alt.Y('favorite_count'), 
    color = 'dog_stage').properties(title = 'Retweets and Likes are strongly correlated')
# Out:
# alt.Chart(...)

# %%
alt.Chart(tweets_master[tweets_master['dog_stage']!= 'unknown']).mark_bar(color='green', opacity=0.5).encode(
    alt.Y('dog_stage', axis=alt.Axis(title='Dog Stage')),
    x='count()'
).properties(title = 'Most dogs rated are puppers')
# Out:
# alt.Chart(...)

# %%
alt.Chart(tweets_master[tweets_master['dog_stage']!= 'unknown']).mark_bar(color='firebrick', opacity=0.5).encode(
    alt.Y('dog_stage', axis=alt.Axis(title='Dog Stage')),
    alt.X('average(favorite_count)', axis=alt.Axis(title='Average Like Count'))
).properties(title = 'People really like puppos')
# Out:
# alt.Chart(...)

# %%
alt.Chart(tweets_master[tweets_master['dog_stage']!= 'unknown']).mark_bar(color='firebrick', opacity=0.5).encode(
    alt.Y('dog_stage', axis=alt.Axis(title='Dog Stage')),
    alt.X('average(retweet_count)', axis=alt.Axis(title='Average Retweet Count'))
).properties(title = 'People really like puppos')
# Out:
# alt.Chart(...)

# %%
alt.Chart(tweets_master[tweets_master['dog_stage']!= 'unknown']).mark_bar(color='firebrick', opacity=0.5).encode(
    alt.Y('dog_stage', axis=alt.Axis(title='Dog Stage')),
    alt.X('average(rating_numerator)', axis=alt.Axis(title='Average Rating'))
).properties(title = 'Best rated dogs are puppos')
# Out:
# alt.Chart(...)

# %%
base = alt.Chart(tweets_master)

bar = base.mark_bar(color='lightblue', opacity=0.9).encode(
    alt.X('favorite_count', axis=alt.Axis(title='Likes'),
          bin=alt.Bin(maxbins=100, extent=([0,50000]))),
    y='count()'
).properties(title = 'Followers engage a lot with almost every WeRateDogs tweet ')

rule = base.mark_rule(color='red').encode(
    x='mean(favorite_count):Q',
    size=alt.value(2)
)

bar + rule
# Out:
# alt.LayerChart(...)

# %%
base = alt.Chart(tweets_master)

bar = base.mark_bar(color='lightblue', opacity=0.9).encode(
    alt.X('retweet_count', axis=alt.Axis(title='Retweets'),
          bin=alt.Bin(maxbins=100, extent=([0,16000]))),
    y='count()'
).properties(title = 'Followers engage a lot with almost every WeRateDogs tweet ')

rule = base.mark_rule(color='red').encode(
    x='mean(retweet_count):Q',
    size=alt.value(2)
)

bar + rule
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Reflexion
#
# I thought Data Wrangling was going to be the easiest and fastest of all lessons in the DAND. However, when I started the project, I quickly realized that I needed to put much more work on it. Already in the gathering phase, specifically querying Twitter’s API, it was clear that I needed to go over the material again, take notes, and practice in my own Jupyter Notebook. I found useful the structure (define, code, test) proposed for the cleaning process, but in my clase it was clear that I needed flexibility and iteration. I had to go back to cleaning more, even until the last chart was produced. I believe sticking to the process is a must, especially when dealing with multiple sources of messy and untidy data. Although it was recommended to start by solving tidiness issues, in this case removing first the unnecessary rows with retweets and replies, followed by the organisation in tables of observational units was important. When cleaning the datasets, I felt like I was being able to put into practice many of the skills I have been learning over the last months. Extracting HTML contents from a tag within the column of a pandas dataframe using BeautifulSoup was a nice accomplishment. I have been working with relational databases for a while now, and I had already developed the sense to understand when observational units are not in their own tables. I ended up keeping separate tables for tweets, dogs and predictions. What I wasn’t sure about was whether a master dataset made sense because having different row counts makes the result different as what you expect. The key is to keep in mind whether you want to keep dogs or tweets as main organisational unit in a master dataset. When creating charts for the last section of the project, I really missed R’s ggplot. I started using matplotlib but was quickly drawn to look for other options, which brought me to the Altair library. I read its documentation and plotted my visualizations on it. Although I found Altair intuitive to use, when I looked under the hood I realized that every chart makes a copy of the whole dataset in JSON format, which makes it less than ideal when working with large datasets or when performing EDA with tons of visualizations.
